# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
#Discretización
N=25
x = np.linspace(-4,4,N)
y = np.linspace(-4,4,N)
H = x[1]-x[0]
#h es el paso
#Generamos con el producto cruz de X y Y el set de --
#-- puntos (x,y) de la región A = [-4,4]x[-4,4], con 25 --
#--puntos en cada eje

# %%
#Definimos lo valores constantes para la función potencial
R = 2 #radio del cilindro (cm)
V = 2 #Velocidad (cm/s)
#Definimos la función potencial

def Potencial(x,y):
    res = (1-((R**2)/((x**2)+(y**2))))
    return V*x*res

# %%
X,Y =np.meshgrid(x,y)
P = Potencial_flujo(X,Y)
h = 0.001
# Out:
# <ipython-input-512-99948698ee20>:7: RuntimeWarning: divide by zero encountered in true_divide
#   return (V-((V*(R**2))/((x**2)+(y**2))))

# %%
def Dx(f,x,y,h):
    return (f(x+h,y)-f(x-h,y))/(2*h)
def Dy(f,x,y,h):
    return (f(x,y+h)-f(x,y-h))/(2*h)

# %%
Ex = np.zeros((N,N))
Ey = np.zeros((N,N))

for i in range(N):
    for j in range(N):
        Ex[i,j] = Dx(Potencial,x[i],y[j],h)
        Ey[i,j] = Dy(Potencial,x[i],y[j],h)

    
Ex = Ex.T
Ey = Ey.T

# %%
fig1 = plt.figure(figsize=(5,5))
ax = fig1.add_subplot(1,1,1)

for i in range(1,len(x)):
    for j in range(1,len(y)):
        ax.quiver(x[i],y[j],Ex[i,j],Ey[i,j],color='r')
