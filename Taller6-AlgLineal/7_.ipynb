# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(r):
    return r[0]**2+r[1]**2+r[2]**2+r[3]**2-1
G = (f,)

# %%
def GetVectorF(G,r):
    v = G[0](r)
    return np.array([v])

# %%
def GetMetric(G,r):
    v = GetVectorF(G,r)
    return np.linalg.norm(v)

# %%
def GetJacobian(G,r,h=1e-6):
    dim = len(G)
    J = np.zeros((dim,4))
    
    for i in range(dim):
        for j in range(4):
            aux = np.zeros(4)
            aux[j] = h
            J[i,j] = (  G[i](r+aux) - G[i](r-aux) )/(2*h)
        
    return J.T

# %%
def Point(Min=-1,Max=1):
    p = [np.random.uniform(Min,Max),np.random.uniform(Min,Max),np.random.uniform(Min,Max),np.random.uniform(Min,Max)]
    return p

# %%
def GetSolve(G,r,lr=1e-3,epochs=int(1e5),error=1e-7):
    
    d = 1
    it = 0
    Vector_F = np.array([])
    R_vector = np.array(r)
    
    while d > error and it < epochs:
        CurrentF = GetMetric(G,r)
        J = GetJacobian(G,r)
        GVector = GetVectorF(G,r)

        #Machine Learning
        r -= lr*np.dot(J,GVector) 
        R_vector = np.vstack((R_vector,r))
        NewF = GetMetric(G,r)
        
        Vector_F = np.append(Vector_F,NewF)
        d = np.abs( CurrentF - NewF )/NewF
        it += 1
        
    if d < error:
        print(' Entrenamiento completo ', d, 'iteraciones', it)
        
    if it == epochs:
        print(' Entrenamiento no completado ')
        
    return r,it,Vector_F,R_vector

# %%
N = 1e3
points = np.zeros((int(N),4))

for i in range(int(N)):
    sol,it,vect,rvect=GetSolve(G,Point())
    points[i,0]= sol[0]
    points[i,1]= sol[1]
    points[i,2]= sol[2]
    points[i,3]= sol[3]
# Out:
#  Entrenamiento completo  0.0 iteraciones 7198
#  Entrenamiento completo  0.0 iteraciones 7068
#  Entrenamiento completo  0.0 iteraciones 6993
#  Entrenamiento completo  0.0 iteraciones 7235
#  Entrenamiento completo  0.0 iteraciones 6570
#  Entrenamiento completo  0.0 iteraciones 7278
#  Entrenamiento completo  0.0 iteraciones 7410
#  Entrenamiento completo  0.0 iteraciones 7646
#  Entrenamiento completo  0.0 iteraciones 6201
#  Entrenamiento completo  0.0 iteraciones 7334
#  Entrenamiento completo  0.0 iteraciones 7169
#  Entrenamiento completo  0.0 iteraciones 7060
#  Entrenamiento completo  0.0 iteraciones 7497
#  Entrenamiento completo  0.0 iteraciones 7417
#  Entrenamiento completo  0.0 iteraciones 7319
#  Entrenamiento completo  0.0 iteraciones 7146
#  Entrenamiento completo  0.0 iteraciones 7322
#  Entrenamiento completo  0.0 iteraciones 6974
#  Entrenamiento completo  0.0 iteraciones 6805
#  Entrenamiento completo  0.0 iteraciones 7094
#  Entrenamiento completo  0.0 iteraciones 6884
#  Entrenamiento completo  0.0 iteraciones 7169
#  Entrenamiento completo  0.0 iteraciones 7086
#  Entrenamiento completo  0.0 iteraciones 7486
#  Entrenamiento completo  0.0 iteraciones 7293
#  Entrenamiento completo  0.0 iteraciones 7390
#  Entrenamiento completo  0.0 iteraciones 7082
#  Entrenamiento completo  0.0 iteraciones 7317
#  Entrenamiento completo  0.0 iteraciones 7392
#  Entrenamiento completo  0.0 iteraciones 7244
#  Entrenamiento completo  0.0 iteraciones 7186
#  Entrenamiento completo  0.0 iteraciones 7503
#  Entrenamiento completo  0.0 iteraciones 7370
#  Entrenamiento completo  0.0 iteraciones 7518
#  Entrenamiento completo  0.0 iteraciones 7255
#  Entrenamiento completo  0.0 iteraciones 7353
#  Entrenamiento completo  0.0 iteraciones 7175
#  Entrenamiento completo  0.0 iteraciones 7564
#  Entrenamiento completo  0.0 iteraciones 7367
#  Entrenamiento completo  0.0 iteraciones 7487
#  Entrenamiento completo  0.0 iteraciones 7298
#  Entrenamiento completo  0.0 iteraciones 7472
#  Entrenamiento completo  0.0 iteraciones 7107
#  Entrenamiento completo  0.0 iteraciones 6877
#  Entrenamiento completo  0.0 iteraciones 7389
#  Entrenamiento completo  0.0 iteraciones 7279
#  Entrenamiento completo  0.0 iteraciones 7047
#  Entrenamiento completo  0.0 iteraciones 6889
#  Entrenamiento completo  0.0 iteraciones 7377
#  Entrenamiento completo  0.0 iteraciones 8174
#  Entrenamiento completo  0.0 iteraciones 7302
#  Entrenamiento completo  0.0 iteraciones 7459
#  Entrenamiento completo  0.0 iteraciones 6953
#  Entrenamiento completo  0.0 iteraciones 7353
#  Entrenamiento completo  0.0 iteraciones 7396
#  Entrenamiento completo  0.0 iteraciones 7392
#  Entrenamiento completo  0.0 iteraciones 7313
#  Entrenamiento completo  0.0 iteraciones 7622
#  Entrenamiento completo  0.0 iteraciones 7179
#  Entrenamiento completo  0.0 iteraciones 7491
#  Entrenamiento completo  0.0 iteraciones 7216
#  Entrenamiento completo  0.0 iteraciones 7100
#  Entrenamiento completo  0.0 iteraciones 7365
#  Entrenamiento completo  0.0 iteraciones 7406
#  Entrenamiento completo  0.0 iteraciones 7119
#  Entrenamiento completo  0.0 iteraciones 7437
#  Entrenamiento completo  0.0 iteraciones 7330
#  Entrenamiento completo  0.0 iteraciones 7098
#  Entrenamiento completo  0.0 iteraciones 7357
#  Entrenamiento completo  0.0 iteraciones 6718
#  Entrenamiento completo  0.0 iteraciones 7472
#  Entrenamiento completo  0.0 iteraciones 7278
#  Entrenamiento completo  0.0 iteraciones 7188
#  Entrenamiento completo  0.0 iteraciones 7397
#  Entrenamiento completo  0.0 iteraciones 7250
#  Entrenamiento completo  0.0 iteraciones 7486
#  Entrenamiento completo  0.0 iteraciones 7205
#  Entrenamiento completo  0.0 iteraciones 7574
#  Entrenamiento completo  0.0 iteraciones 7508
#  Entrenamiento completo  0.0 iteraciones 7681
#  Entrenamiento completo  0.0 iteraciones 7207
#  Entrenamiento completo  0.0 iteraciones 7260
#  Entrenamiento completo  0.0 iteraciones 7499
#  Entrenamiento completo  0.0 iteraciones 7091
#  Entrenamiento completo  0.0 iteraciones 7108
#  Entrenamiento completo  0.0 iteraciones 7015
#  Entrenamiento completo  0.0 iteraciones 6856
#  Entrenamiento completo  0.0 iteraciones 7893
#  Entrenamiento completo  0.0 iteraciones 7427
#  Entrenamiento completo  0.0 iteraciones 7332
#  Entrenamiento completo  0.0 iteraciones 7145
#  Entrenamiento completo  0.0 iteraciones 7405
#  Entrenamiento completo  0.0 iteraciones 7767
#  Entrenamiento completo  0.0 iteraciones 6957
#  Entrenamiento completo  0.0 iteraciones 7781
#  Entrenamiento completo  0.0 iteraciones 7040
#  Entrenamiento completo  0.0 iteraciones 8317
#  Entrenamiento completo  0.0 iteraciones 7387
#  Entrenamiento completo  0.0 iteraciones 7071
#  Entrenamiento completo  0.0 iteraciones 7428
#  Entrenamiento completo  0.0 iteraciones 7254
#  Entrenamiento completo  0.0 iteraciones 7648
#  Entrenamiento completo  0.0 iteraciones 6970
#  Entrenamiento completo  0.0 iteraciones 7408
#  Entrenamiento completo  0.0 iteraciones 7859
#  Entrenamiento completo  0.0 iteraciones 7393
#  Entrenamiento completo  0.0 iteraciones 7617
#  Entrenamiento completo  0.0 iteraciones 7183
#  Entrenamiento completo  0.0 iteraciones 7237
#  Entrenamiento completo  0.0 iteraciones 7246
#  Entrenamiento completo  0.0 iteraciones 7150
#  Entrenamiento completo  0.0 iteraciones 7202
#  Entrenamiento completo  0.0 iteraciones 7080
#  Entrenamiento completo  0.0 iteraciones 7221
#  Entrenamiento completo  0.0 iteraciones 6734
#  Entrenamiento completo  0.0 iteraciones 7343
#  Entrenamiento completo  0.0 iteraciones 7101
#  Entrenamiento completo  0.0 iteraciones 7438
#  Entrenamiento completo  0.0 iteraciones 7513
#  Entrenamiento completo  0.0 iteraciones 7066
#  Entrenamiento completo  0.0 iteraciones 7346
#  Entrenamiento completo  0.0 iteraciones 7570
#  Entrenamiento completo  0.0 iteraciones 7286
#  Entrenamiento completo  0.0 iteraciones 7254
#  Entrenamiento completo  0.0 iteraciones 7365
#  Entrenamiento completo  0.0 iteraciones 7423
#  Entrenamiento completo  0.0 iteraciones 7394
#  Entrenamiento completo  0.0 iteraciones 7080
#  Entrenamiento completo  0.0 iteraciones 7289
#  Entrenamiento completo  0.0 iteraciones 8206
#  Entrenamiento completo  0.0 iteraciones 6721
#  Entrenamiento completo  0.0 iteraciones 6846
#  Entrenamiento completo  0.0 iteraciones 7827
#  Entrenamiento completo  0.0 iteraciones 6822
#  Entrenamiento completo  0.0 iteraciones 7433
#  Entrenamiento completo  0.0 iteraciones 7321
#  Entrenamiento completo  0.0 iteraciones 7457
#  Entrenamiento completo  0.0 iteraciones 7435
#  Entrenamiento completo  0.0 iteraciones 7430
#  Entrenamiento completo  0.0 iteraciones 7216
#  Entrenamiento completo  0.0 iteraciones 7446
#  Entrenamiento completo  0.0 iteraciones 7142
#  Entrenamiento completo  0.0 iteraciones 7490
#  Entrenamiento completo  0.0 iteraciones 7239
#  Entrenamiento completo  0.0 iteraciones 7235
#  Entrenamiento completo  0.0 iteraciones 7452
#  Entrenamiento completo  0.0 iteraciones 7837
#  Entrenamiento completo  0.0 iteraciones 7243
#  Entrenamiento completo  0.0 iteraciones 7033
#  Entrenamiento completo  0.0 iteraciones 7212
#  Entrenamiento completo  0.0 iteraciones 7414
#  Entrenamiento completo  0.0 iteraciones 7170
#  Entrenamiento completo  0.0 iteraciones 7256
#  Entrenamiento completo  0.0 iteraciones 7478
#  Entrenamiento completo  0.0 iteraciones 7239
#  Entrenamiento completo  0.0 iteraciones 7656
#  Entrenamiento completo  0.0 iteraciones 7452
#  Entrenamiento completo  0.0 iteraciones 7679
#  Entrenamiento completo  0.0 iteraciones 6909
#  Entrenamiento completo  0.0 iteraciones 7387
#  Entrenamiento completo  0.0 iteraciones 7392
#  Entrenamiento completo  0.0 iteraciones 7401
#  Entrenamiento completo  0.0 iteraciones 7142
#  Entrenamiento completo  0.0 iteraciones 7883
#  Entrenamiento completo  0.0 iteraciones 7674
#  Entrenamiento completo  0.0 iteraciones 6548
#  Entrenamiento completo  0.0 iteraciones 7088
#  Entrenamiento completo  0.0 iteraciones 7101
#  Entrenamiento completo  0.0 iteraciones 6859
#  Entrenamiento completo  0.0 iteraciones 7297
#  Entrenamiento completo  0.0 iteraciones 7289
#  Entrenamiento completo  0.0 iteraciones 6507
#  Entrenamiento completo  0.0 iteraciones 7001
#  Entrenamiento completo  0.0 iteraciones 7860
#  Entrenamiento completo  0.0 iteraciones 7307
#  Entrenamiento completo  0.0 iteraciones 7319
#  Entrenamiento completo  0.0 iteraciones 7497
#  Entrenamiento completo  0.0 iteraciones 7212
#  Entrenamiento completo  0.0 iteraciones 7318
#  Entrenamiento completo  0.0 iteraciones 7020
#  Entrenamiento completo  0.0 iteraciones 7294
#  Entrenamiento completo  0.0 iteraciones 7187
#  Entrenamiento completo  0.0 iteraciones 7387
#  Entrenamiento completo  0.0 iteraciones 7284
#  Entrenamiento completo  0.0 iteraciones 7225
#  Entrenamiento completo  0.0 iteraciones 7172
#  Entrenamiento completo  0.0 iteraciones 7373
#  Entrenamiento completo  0.0 iteraciones 7384
#  Entrenamiento completo  0.0 iteraciones 7262
#  Entrenamiento completo  0.0 iteraciones 6463
#  Entrenamiento completo  0.0 iteraciones 6949
#  Entrenamiento completo  0.0 iteraciones 7690
#  Entrenamiento completo  0.0 iteraciones 7142
#  Entrenamiento completo  0.0 iteraciones 8000
#  Entrenamiento completo  0.0 iteraciones 7198
#  Entrenamiento completo  0.0 iteraciones 7411
#  Entrenamiento completo  0.0 iteraciones 6980
#  Entrenamiento completo  0.0 iteraciones 7506
#  Entrenamiento completo  0.0 iteraciones 7168
#  Entrenamiento completo  0.0 iteraciones 7655
#  Entrenamiento completo  0.0 iteraciones 7427
#  Entrenamiento completo  0.0 iteraciones 7297
#  Entrenamiento completo  0.0 iteraciones 6992
#  Entrenamiento completo  0.0 iteraciones 7682
#  Entrenamiento completo  0.0 iteraciones 7291
#  Entrenamiento completo  0.0 iteraciones 7664
#  Entrenamiento completo  0.0 iteraciones 6851
#  Entrenamiento completo  0.0 iteraciones 7143
#  Entrenamiento completo  0.0 iteraciones 7759
#  Entrenamiento completo  0.0 iteraciones 7462
#  Entrenamiento completo  0.0 iteraciones 7453
#  Entrenamiento completo  0.0 iteraciones 7465
#  Entrenamiento completo  0.0 iteraciones 7240
#  Entrenamiento completo  0.0 iteraciones 7060
#  Entrenamiento completo  0.0 iteraciones 7268
#  Entrenamiento completo  0.0 iteraciones 7229
#  Entrenamiento completo  0.0 iteraciones 7262
#  Entrenamiento completo  0.0 iteraciones 7179
#  Entrenamiento completo  0.0 iteraciones 6894
#  Entrenamiento completo  0.0 iteraciones 7405
#  Entrenamiento completo  0.0 iteraciones 6812
#  Entrenamiento completo  0.0 iteraciones 7494
#  Entrenamiento completo  0.0 iteraciones 7005
#  Entrenamiento completo  0.0 iteraciones 6969
#  Entrenamiento completo  0.0 iteraciones 7163
#  Entrenamiento completo  0.0 iteraciones 6921
#  Entrenamiento completo  0.0 iteraciones 7283
#  Entrenamiento completo  0.0 iteraciones 7369
#  Entrenamiento completo  0.0 iteraciones 7304
#  Entrenamiento completo  0.0 iteraciones 7061
#  Entrenamiento completo  0.0 iteraciones 7136
#  Entrenamiento completo  0.0 iteraciones 6688
#  Entrenamiento completo  0.0 iteraciones 7168
#  Entrenamiento completo  0.0 iteraciones 7677
#  Entrenamiento completo  0.0 iteraciones 7526
#  Entrenamiento completo  0.0 iteraciones 7639
#  Entrenamiento completo  0.0 iteraciones 6938
#  Entrenamiento completo  0.0 iteraciones 7936
#  Entrenamiento completo  0.0 iteraciones 7293
#  Entrenamiento completo  0.0 iteraciones 7292
#  Entrenamiento completo  0.0 iteraciones 7141
#  Entrenamiento completo  0.0 iteraciones 7219
#  Entrenamiento completo  0.0 iteraciones 7442
#  Entrenamiento completo  0.0 iteraciones 7552
#  Entrenamiento completo  0.0 iteraciones 7001
#  Entrenamiento completo  0.0 iteraciones 7195
#  Entrenamiento completo  0.0 iteraciones 7138
#  Entrenamiento completo  0.0 iteraciones 7949
#  Entrenamiento completo  0.0 iteraciones 7425
#  Entrenamiento completo  0.0 iteraciones 6872
#  Entrenamiento completo  0.0 iteraciones 7448
#  Entrenamiento completo  0.0 iteraciones 7264
#  Entrenamiento completo  0.0 iteraciones 7526
#  Entrenamiento completo  0.0 iteraciones 7497
#  Entrenamiento completo  0.0 iteraciones 7217
#  Entrenamiento completo  0.0 iteraciones 7118
#  Entrenamiento completo  0.0 iteraciones 7563
#  Entrenamiento completo  0.0 iteraciones 7271
#  Entrenamiento completo  0.0 iteraciones 7069
#  Entrenamiento completo  0.0 iteraciones 7964
#  Entrenamiento completo  0.0 iteraciones 7486
#  Entrenamiento completo  0.0 iteraciones 7655
#  Entrenamiento completo  0.0 iteraciones 7328
#  Entrenamiento completo  0.0 iteraciones 7368
#  Entrenamiento completo  0.0 iteraciones 7218
#  Entrenamiento completo  0.0 iteraciones 7393
#  Entrenamiento completo  0.0 iteraciones 6585
#  Entrenamiento completo  0.0 iteraciones 7380
#  Entrenamiento completo  0.0 iteraciones 7500
#  Entrenamiento completo  0.0 iteraciones 7257
#  Entrenamiento completo  0.0 iteraciones 7004
#  Entrenamiento completo  0.0 iteraciones 7472
#  Entrenamiento completo  0.0 iteraciones 7562
#  Entrenamiento completo  0.0 iteraciones 7730
#  Entrenamiento completo  0.0 iteraciones 7443
#  Entrenamiento completo  0.0 iteraciones 7201
#  Entrenamiento completo  0.0 iteraciones 6949
#  Entrenamiento completo  0.0 iteraciones 7222
#  Entrenamiento completo  0.0 iteraciones 6921
#  Entrenamiento completo  0.0 iteraciones 7681
#  Entrenamiento completo  0.0 iteraciones 7382
#  Entrenamiento completo  0.0 iteraciones 7502
#  Entrenamiento completo  0.0 iteraciones 7183
#  Entrenamiento completo  0.0 iteraciones 7180
#  Entrenamiento completo  0.0 iteraciones 6872
#  Entrenamiento completo  0.0 iteraciones 7578
#  Entrenamiento completo  0.0 iteraciones 7134
#  Entrenamiento completo  0.0 iteraciones 6991
#  Entrenamiento completo  0.0 iteraciones 7377
#  Entrenamiento completo  0.0 iteraciones 7012
#  Entrenamiento completo  0.0 iteraciones 6955
#  Entrenamiento completo  0.0 iteraciones 6816
#  Entrenamiento completo  0.0 iteraciones 7277
#  Entrenamiento completo  0.0 iteraciones 7311
#  Entrenamiento completo  0.0 iteraciones 7849
#  Entrenamiento completo  0.0 iteraciones 7238
#  Entrenamiento completo  0.0 iteraciones 7110
#  Entrenamiento completo  0.0 iteraciones 7369
#  Entrenamiento completo  0.0 iteraciones 7057
#  Entrenamiento completo  0.0 iteraciones 6172
#  Entrenamiento completo  0.0 iteraciones 7193
#  Entrenamiento completo  0.0 iteraciones 7355
#  Entrenamiento completo  0.0 iteraciones 7685
#  Entrenamiento completo  0.0 iteraciones 7335
#  Entrenamiento completo  0.0 iteraciones 7191
#  Entrenamiento completo  0.0 iteraciones 7322
#  Entrenamiento completo  0.0 iteraciones 7352
#  Entrenamiento completo  0.0 iteraciones 7541
#  Entrenamiento completo  0.0 iteraciones 6762
#  Entrenamiento completo  0.0 iteraciones 7223
#  Entrenamiento completo  0.0 iteraciones 7061
#  Entrenamiento completo  0.0 iteraciones 7242
#  Entrenamiento completo  0.0 iteraciones 7231
#  Entrenamiento completo  0.0 iteraciones 7210
#  Entrenamiento completo  0.0 iteraciones 7232
#  Entrenamiento completo  0.0 iteraciones 7431
#  Entrenamiento completo  0.0 iteraciones 7211
#  Entrenamiento completo  0.0 iteraciones 7132
#  Entrenamiento completo  0.0 iteraciones 7164
#  Entrenamiento completo  0.0 iteraciones 7261
#  Entrenamiento completo  0.0 iteraciones 7763
#  Entrenamiento completo  0.0 iteraciones 7046
#  Entrenamiento completo  0.0 iteraciones 7315
#  Entrenamiento completo  0.0 iteraciones 7382
#  Entrenamiento completo  0.0 iteraciones 7531
#  Entrenamiento completo  0.0 iteraciones 7173
#  Entrenamiento completo  0.0 iteraciones 6777
#  Entrenamiento completo  0.0 iteraciones 7418
#  Entrenamiento completo  0.0 iteraciones 7143
#  Entrenamiento completo  0.0 iteraciones 7170
#  Entrenamiento completo  0.0 iteraciones 7330
#  Entrenamiento completo  0.0 iteraciones 7394
#  Entrenamiento completo  0.0 iteraciones 7636
#  Entrenamiento completo  0.0 iteraciones 6533
#  Entrenamiento completo  0.0 iteraciones 7515
#  Entrenamiento completo  0.0 iteraciones 6999
#  Entrenamiento completo  0.0 iteraciones 7728
#  Entrenamiento completo  0.0 iteraciones 7238
#  Entrenamiento completo  0.0 iteraciones 7383
#  Entrenamiento completo  0.0 iteraciones 6792
#  Entrenamiento completo  0.0 iteraciones 7377
#  Entrenamiento completo  0.0 iteraciones 7245
#  Entrenamiento completo  0.0 iteraciones 6653
#  Entrenamiento completo  0.0 iteraciones 7277
#  Entrenamiento completo  0.0 iteraciones 7144
#  Entrenamiento completo  0.0 iteraciones 7313
#  Entrenamiento completo  0.0 iteraciones 6693
#  Entrenamiento completo  0.0 iteraciones 7265
#  Entrenamiento completo  0.0 iteraciones 7467
#  Entrenamiento completo  0.0 iteraciones 7276
#  Entrenamiento completo  0.0 iteraciones 7644
#  Entrenamiento completo  0.0 iteraciones 7446
#  Entrenamiento completo  0.0 iteraciones 7305
#  Entrenamiento completo  0.0 iteraciones 7280
#  Entrenamiento completo  0.0 iteraciones 7302
#  Entrenamiento completo  0.0 iteraciones 7361
#  Entrenamiento completo  0.0 iteraciones 6548
#  Entrenamiento completo  0.0 iteraciones 6982
#  Entrenamiento completo  0.0 iteraciones 7453
#  Entrenamiento completo  0.0 iteraciones 7867
#  Entrenamiento completo  0.0 iteraciones 7740
#  Entrenamiento completo  0.0 iteraciones 7408
#  Entrenamiento completo  0.0 iteraciones 7476
#  Entrenamiento completo  0.0 iteraciones 7791
#  Entrenamiento completo  0.0 iteraciones 7062
#  Entrenamiento completo  0.0 iteraciones 7011
#  Entrenamiento completo  0.0 iteraciones 7283
#  Entrenamiento completo  0.0 iteraciones 7137
#  Entrenamiento completo  0.0 iteraciones 7255
#  Entrenamiento completo  0.0 iteraciones 7773
#  Entrenamiento completo  0.0 iteraciones 7195
#  Entrenamiento completo  0.0 iteraciones 7170
#  Entrenamiento completo  0.0 iteraciones 7705
#  Entrenamiento completo  0.0 iteraciones 6400
#  Entrenamiento completo  0.0 iteraciones 7333
#  Entrenamiento completo  0.0 iteraciones 7220
#  Entrenamiento completo  0.0 iteraciones 7206
#  Entrenamiento completo  0.0 iteraciones 7518
#  Entrenamiento completo  0.0 iteraciones 7260
#  Entrenamiento completo  0.0 iteraciones 7750
#  Entrenamiento completo  0.0 iteraciones 7394
#  Entrenamiento completo  0.0 iteraciones 7306
#  Entrenamiento completo  0.0 iteraciones 7121
#  Entrenamiento completo  0.0 iteraciones 7263
#  Entrenamiento completo  0.0 iteraciones 7477
#  Entrenamiento completo  0.0 iteraciones 7380
#  Entrenamiento completo  0.0 iteraciones 7573
#  Entrenamiento completo  0.0 iteraciones 7422
#  Entrenamiento completo  0.0 iteraciones 7402
#  Entrenamiento completo  0.0 iteraciones 6917
#  Entrenamiento completo  0.0 iteraciones 7074
#  Entrenamiento completo  0.0 iteraciones 7187
#  Entrenamiento completo  0.0 iteraciones 7409
#  Entrenamiento completo  0.0 iteraciones 7532
#  Entrenamiento completo  0.0 iteraciones 7362
#  Entrenamiento completo  0.0 iteraciones 6984
#  Entrenamiento completo  0.0 iteraciones 7536
#  Entrenamiento completo  0.0 iteraciones 7266
#  Entrenamiento completo  0.0 iteraciones 7602
#  Entrenamiento completo  0.0 iteraciones 7313
#  Entrenamiento completo  0.0 iteraciones 7497
#  Entrenamiento completo  0.0 iteraciones 7061
#  Entrenamiento completo  0.0 iteraciones 7208
#  Entrenamiento completo  0.0 iteraciones 7323
#  Entrenamiento completo  0.0 iteraciones 8065
#  Entrenamiento completo  0.0 iteraciones 7604
#  Entrenamiento completo  0.0 iteraciones 6694
#  Entrenamiento completo  0.0 iteraciones 7232
#  Entrenamiento completo  0.0 iteraciones 6704
#  Entrenamiento completo  0.0 iteraciones 7239
#  Entrenamiento completo  0.0 iteraciones 7091
#  Entrenamiento completo  0.0 iteraciones 7489
#  Entrenamiento completo  0.0 iteraciones 7631
#  Entrenamiento completo  0.0 iteraciones 7468
#  Entrenamiento completo  0.0 iteraciones 7428
#  Entrenamiento completo  0.0 iteraciones 7489
#  Entrenamiento completo  0.0 iteraciones 7197
#  Entrenamiento completo  0.0 iteraciones 7705
#  Entrenamiento completo  0.0 iteraciones 7286
#  Entrenamiento completo  0.0 iteraciones 7178
#  Entrenamiento completo  0.0 iteraciones 7142
#  Entrenamiento completo  0.0 iteraciones 7201
#  Entrenamiento completo  0.0 iteraciones 7268
#  Entrenamiento completo  0.0 iteraciones 7681
#  Entrenamiento completo  0.0 iteraciones 7216
#  Entrenamiento completo  0.0 iteraciones 6951
#  Entrenamiento completo  0.0 iteraciones 7243
#  Entrenamiento completo  0.0 iteraciones 7262
#  Entrenamiento completo  0.0 iteraciones 7209
#  Entrenamiento completo  0.0 iteraciones 7430
#  Entrenamiento completo  0.0 iteraciones 7440
#  Entrenamiento completo  0.0 iteraciones 7628
#  Entrenamiento completo  0.0 iteraciones 7199
#  Entrenamiento completo  0.0 iteraciones 7286
#  Entrenamiento completo  0.0 iteraciones 7414
#  Entrenamiento completo  0.0 iteraciones 7590
#  Entrenamiento completo  0.0 iteraciones 7904
#  Entrenamiento completo  0.0 iteraciones 7163
#  Entrenamiento completo  0.0 iteraciones 7084
#  Entrenamiento completo  0.0 iteraciones 7472
#  Entrenamiento completo  0.0 iteraciones 7222
#  Entrenamiento completo  0.0 iteraciones 7441
#  Entrenamiento completo  0.0 iteraciones 7251
#  Entrenamiento completo  0.0 iteraciones 7208
#  Entrenamiento completo  0.0 iteraciones 7114
#  Entrenamiento completo  0.0 iteraciones 7457
#  Entrenamiento completo  0.0 iteraciones 6626
#  Entrenamiento completo  0.0 iteraciones 7353
#  Entrenamiento completo  0.0 iteraciones 6893
#  Entrenamiento completo  0.0 iteraciones 7484
#  Entrenamiento completo  0.0 iteraciones 7196
#  Entrenamiento completo  0.0 iteraciones 6747
#  Entrenamiento completo  0.0 iteraciones 7761
#  Entrenamiento completo  0.0 iteraciones 7068
#  Entrenamiento completo  0.0 iteraciones 7230
#  Entrenamiento completo  0.0 iteraciones 7437
#  Entrenamiento completo  0.0 iteraciones 6973
#  Entrenamiento completo  0.0 iteraciones 7254
#  Entrenamiento completo  0.0 iteraciones 7473
#  Entrenamiento completo  0.0 iteraciones 5800
#  Entrenamiento completo  0.0 iteraciones 7961
#  Entrenamiento completo  0.0 iteraciones 7376
#  Entrenamiento completo  0.0 iteraciones 7243
#  Entrenamiento completo  0.0 iteraciones 7120
#  Entrenamiento completo  0.0 iteraciones 6997
#  Entrenamiento completo  0.0 iteraciones 7471
#  Entrenamiento completo  0.0 iteraciones 7383
#  Entrenamiento completo  0.0 iteraciones 7364
#  Entrenamiento completo  0.0 iteraciones 7479
#  Entrenamiento completo  0.0 iteraciones 7467
#  Entrenamiento completo  0.0 iteraciones 7424
#  Entrenamiento completo  0.0 iteraciones 7522
#  Entrenamiento completo  0.0 iteraciones 7483
#  Entrenamiento completo  0.0 iteraciones 7454
#  Entrenamiento completo  0.0 iteraciones 7623
#  Entrenamiento completo  0.0 iteraciones 7447
#  Entrenamiento completo  0.0 iteraciones 7470
#  Entrenamiento completo  0.0 iteraciones 6979
#  Entrenamiento completo  0.0 iteraciones 5980
#  Entrenamiento completo  0.0 iteraciones 7004
#  Entrenamiento completo  0.0 iteraciones 7172
#  Entrenamiento completo  0.0 iteraciones 7339
#  Entrenamiento completo  0.0 iteraciones 8207
#  Entrenamiento completo  0.0 iteraciones 7480
#  Entrenamiento completo  0.0 iteraciones 7192
#  Entrenamiento completo  0.0 iteraciones 7173
#  Entrenamiento completo  0.0 iteraciones 8123
#  Entrenamiento completo  0.0 iteraciones 7740
#  Entrenamiento completo  0.0 iteraciones 7487
#  Entrenamiento completo  0.0 iteraciones 7163
#  Entrenamiento completo  0.0 iteraciones 7287
#  Entrenamiento completo  0.0 iteraciones 7453
#  Entrenamiento completo  0.0 iteraciones 7513
#  Entrenamiento completo  0.0 iteraciones 7470
#  Entrenamiento completo  0.0 iteraciones 7734
#  Entrenamiento completo  0.0 iteraciones 7438
#  Entrenamiento completo  0.0 iteraciones 7961
#  Entrenamiento completo  0.0 iteraciones 7283
#  Entrenamiento completo  0.0 iteraciones 7704
#  Entrenamiento completo  0.0 iteraciones 7233
#  Entrenamiento completo  0.0 iteraciones 7754
#  Entrenamiento completo  0.0 iteraciones 7277
#  Entrenamiento completo  0.0 iteraciones 7344
#  Entrenamiento completo  0.0 iteraciones 7056
#  Entrenamiento completo  0.0 iteraciones 7375
#  Entrenamiento completo  0.0 iteraciones 7029
#  Entrenamiento completo  0.0 iteraciones 7697
#  Entrenamiento completo  0.0 iteraciones 7513
#  Entrenamiento completo  0.0 iteraciones 7237
#  Entrenamiento completo  0.0 iteraciones 7446
#  Entrenamiento completo  0.0 iteraciones 7229
#  Entrenamiento completo  0.0 iteraciones 7511
#  Entrenamiento completo  0.0 iteraciones 7216
#  Entrenamiento completo  0.0 iteraciones 7922
#  Entrenamiento completo  0.0 iteraciones 7442
#  Entrenamiento completo  0.0 iteraciones 7222
#  Entrenamiento completo  0.0 iteraciones 7738
#  Entrenamiento completo  0.0 iteraciones 7234
#  Entrenamiento completo  0.0 iteraciones 7338
#  Entrenamiento completo  0.0 iteraciones 7527
#  Entrenamiento completo  0.0 iteraciones 7159
#  Entrenamiento completo  0.0 iteraciones 7349
#  Entrenamiento completo  0.0 iteraciones 7363
#  Entrenamiento completo  0.0 iteraciones 7216
#  Entrenamiento completo  0.0 iteraciones 7125
#  Entrenamiento completo  0.0 iteraciones 7027
#  Entrenamiento completo  0.0 iteraciones 7390
#  Entrenamiento completo  0.0 iteraciones 7303
#  Entrenamiento completo  0.0 iteraciones 7409
#  Entrenamiento completo  0.0 iteraciones 7398
#  Entrenamiento completo  0.0 iteraciones 7477
#  Entrenamiento completo  0.0 iteraciones 7265
#  Entrenamiento completo  0.0 iteraciones 7213
#  Entrenamiento completo  0.0 iteraciones 7928
#  Entrenamiento completo  0.0 iteraciones 6700
#  Entrenamiento completo  0.0 iteraciones 7352
#  Entrenamiento completo  0.0 iteraciones 7288
#  Entrenamiento completo  0.0 iteraciones 6975
#  Entrenamiento completo  0.0 iteraciones 6841
#  Entrenamiento completo  0.0 iteraciones 6930
#  Entrenamiento completo  0.0 iteraciones 7603
#  Entrenamiento completo  0.0 iteraciones 7069
#  Entrenamiento completo  0.0 iteraciones 7235
#  Entrenamiento completo  0.0 iteraciones 7343
#  Entrenamiento completo  0.0 iteraciones 7212
#  Entrenamiento completo  0.0 iteraciones 7259
#  Entrenamiento completo  0.0 iteraciones 7410
#  Entrenamiento completo  0.0 iteraciones 7025
#  Entrenamiento completo  0.0 iteraciones 7397
#  Entrenamiento completo  0.0 iteraciones 7029
#  Entrenamiento completo  0.0 iteraciones 7201
#  Entrenamiento completo  0.0 iteraciones 7082
#  Entrenamiento completo  0.0 iteraciones 6522
#  Entrenamiento completo  0.0 iteraciones 7389
#  Entrenamiento completo  0.0 iteraciones 7096
#  Entrenamiento completo  0.0 iteraciones 7379
#  Entrenamiento completo  0.0 iteraciones 7486
#  Entrenamiento completo  0.0 iteraciones 7023
#  Entrenamiento completo  0.0 iteraciones 7261
#  Entrenamiento completo  0.0 iteraciones 7463
#  Entrenamiento completo  0.0 iteraciones 7493
#  Entrenamiento completo  0.0 iteraciones 5047
#  Entrenamiento completo  0.0 iteraciones 7241
#  Entrenamiento completo  0.0 iteraciones 7351
#  Entrenamiento completo  0.0 iteraciones 7485
#  Entrenamiento completo  0.0 iteraciones 7218
#  Entrenamiento completo  0.0 iteraciones 7283
#  Entrenamiento completo  0.0 iteraciones 7493
#  Entrenamiento completo  0.0 iteraciones 7773
#  Entrenamiento completo  0.0 iteraciones 7259
#  Entrenamiento completo  0.0 iteraciones 7162
#  Entrenamiento completo  0.0 iteraciones 7832
#  Entrenamiento completo  0.0 iteraciones 7145
#  Entrenamiento completo  0.0 iteraciones 7497
#  Entrenamiento completo  0.0 iteraciones 7222
#  Entrenamiento completo  0.0 iteraciones 8031
#  Entrenamiento completo  0.0 iteraciones 7158
#  Entrenamiento completo  0.0 iteraciones 6877
#  Entrenamiento completo  0.0 iteraciones 7195
#  Entrenamiento completo  0.0 iteraciones 7349
#  Entrenamiento completo  0.0 iteraciones 7557
#  Entrenamiento completo  0.0 iteraciones 7135
#  Entrenamiento completo  0.0 iteraciones 6712
#  Entrenamiento completo  0.0 iteraciones 7311
#  Entrenamiento completo  0.0 iteraciones 7012
#  Entrenamiento completo  0.0 iteraciones 6661
#  Entrenamiento completo  0.0 iteraciones 7283
#  Entrenamiento completo  0.0 iteraciones 7279
#  Entrenamiento completo  0.0 iteraciones 7397
#  Entrenamiento completo  0.0 iteraciones 7397
#  Entrenamiento completo  0.0 iteraciones 6678
#  Entrenamiento completo  0.0 iteraciones 7328
#  Entrenamiento completo  0.0 iteraciones 7432
#  Entrenamiento completo  0.0 iteraciones 7264
#  Entrenamiento completo  0.0 iteraciones 6861
#  Entrenamiento completo  0.0 iteraciones 7473
#  Entrenamiento completo  0.0 iteraciones 7487
#  Entrenamiento completo  0.0 iteraciones 7380
#  Entrenamiento completo  0.0 iteraciones 7336
#  Entrenamiento completo  0.0 iteraciones 7271
#  Entrenamiento completo  0.0 iteraciones 8188
#  Entrenamiento completo  0.0 iteraciones 6949
#  Entrenamiento completo  0.0 iteraciones 7440
#  Entrenamiento completo  0.0 iteraciones 7234
#  Entrenamiento completo  0.0 iteraciones 7287
#  Entrenamiento completo  0.0 iteraciones 7131
#  Entrenamiento completo  0.0 iteraciones 7351
#  Entrenamiento completo  0.0 iteraciones 7484
#  Entrenamiento completo  0.0 iteraciones 7462
#  Entrenamiento completo  0.0 iteraciones 7689
#  Entrenamiento completo  0.0 iteraciones 7592
#  Entrenamiento completo  0.0 iteraciones 7227
#  Entrenamiento completo  0.0 iteraciones 7701
#  Entrenamiento completo  0.0 iteraciones 7632
#  Entrenamiento completo  0.0 iteraciones 6935
#  Entrenamiento completo  0.0 iteraciones 6947
#  Entrenamiento completo  0.0 iteraciones 7375
#  Entrenamiento completo  0.0 iteraciones 7185
#  Entrenamiento completo  0.0 iteraciones 7218
#  Entrenamiento completo  0.0 iteraciones 7080
#  Entrenamiento completo  0.0 iteraciones 7754
#  Entrenamiento completo  0.0 iteraciones 7757
#  Entrenamiento completo  0.0 iteraciones 6892
#  Entrenamiento completo  0.0 iteraciones 7361
#  Entrenamiento completo  0.0 iteraciones 7519
#  Entrenamiento completo  0.0 iteraciones 7258
#  Entrenamiento completo  0.0 iteraciones 7637
#  Entrenamiento completo  0.0 iteraciones 7199
#  Entrenamiento completo  0.0 iteraciones 7376
#  Entrenamiento completo  0.0 iteraciones 7777
#  Entrenamiento completo  0.0 iteraciones 7461
#  Entrenamiento completo  0.0 iteraciones 7278
#  Entrenamiento completo  0.0 iteraciones 7444
#  Entrenamiento completo  0.0 iteraciones 7467
#  Entrenamiento completo  0.0 iteraciones 7424
#  Entrenamiento completo  0.0 iteraciones 6943
#  Entrenamiento completo  0.0 iteraciones 7209
#  Entrenamiento completo  0.0 iteraciones 7072
#  Entrenamiento completo  0.0 iteraciones 7202
#  Entrenamiento completo  0.0 iteraciones 7302
#  Entrenamiento completo  0.0 iteraciones 6675
#  Entrenamiento completo  0.0 iteraciones 7435
#  Entrenamiento completo  0.0 iteraciones 6892
#  Entrenamiento completo  0.0 iteraciones 7398
#  Entrenamiento completo  0.0 iteraciones 6741
#  Entrenamiento completo  0.0 iteraciones 7418
#  Entrenamiento completo  0.0 iteraciones 7285
#  Entrenamiento completo  0.0 iteraciones 7018
#  Entrenamiento completo  0.0 iteraciones 7210
#  Entrenamiento completo  0.0 iteraciones 7292
#  Entrenamiento completo  0.0 iteraciones 7598
#  Entrenamiento completo  0.0 iteraciones 7494
#  Entrenamiento completo  0.0 iteraciones 7379
#  Entrenamiento completo  0.0 iteraciones 7951
#  Entrenamiento completo  0.0 iteraciones 7228
#  Entrenamiento completo  0.0 iteraciones 7982
#  Entrenamiento completo  0.0 iteraciones 7297
#  Entrenamiento completo  0.0 iteraciones 7446
#  Entrenamiento completo  0.0 iteraciones 7187
#  Entrenamiento completo  0.0 iteraciones 7234
#  Entrenamiento completo  0.0 iteraciones 7009
#  Entrenamiento completo  0.0 iteraciones 7075
#  Entrenamiento completo  0.0 iteraciones 7329
#  Entrenamiento completo  0.0 iteraciones 7067
#  Entrenamiento completo  0.0 iteraciones 7446
#  Entrenamiento completo  0.0 iteraciones 6757
#  Entrenamiento completo  0.0 iteraciones 6982
#  Entrenamiento completo  0.0 iteraciones 7313
#  Entrenamiento completo  0.0 iteraciones 7451
#  Entrenamiento completo  0.0 iteraciones 7843
#  Entrenamiento completo  0.0 iteraciones 7431
#  Entrenamiento completo  0.0 iteraciones 6952
#  Entrenamiento completo  0.0 iteraciones 7399
#  Entrenamiento completo  0.0 iteraciones 7149
#  Entrenamiento completo  0.0 iteraciones 7966
#  Entrenamiento completo  0.0 iteraciones 7045
#  Entrenamiento completo  0.0 iteraciones 6825
#  Entrenamiento completo  0.0 iteraciones 7290
#  Entrenamiento completo  0.0 iteraciones 7417
#  Entrenamiento completo  0.0 iteraciones 7646
#  Entrenamiento completo  0.0 iteraciones 7464
#  Entrenamiento completo  0.0 iteraciones 7233
#  Entrenamiento completo  0.0 iteraciones 7736
#  Entrenamiento completo  0.0 iteraciones 7153
#  Entrenamiento completo  0.0 iteraciones 6427
#  Entrenamiento completo  0.0 iteraciones 7814
#  Entrenamiento completo  0.0 iteraciones 7571
#  Entrenamiento completo  0.0 iteraciones 7138
#  Entrenamiento completo  0.0 iteraciones 6935
#  Entrenamiento completo  0.0 iteraciones 7335
#  Entrenamiento completo  0.0 iteraciones 7364
#  Entrenamiento completo  0.0 iteraciones 7239
#  Entrenamiento completo  0.0 iteraciones 7456
#  Entrenamiento completo  0.0 iteraciones 7317
#  Entrenamiento completo  0.0 iteraciones 7323
#  Entrenamiento completo  0.0 iteraciones 8188
#  Entrenamiento completo  0.0 iteraciones 7134
#  Entrenamiento completo  0.0 iteraciones 7553
#  Entrenamiento completo  0.0 iteraciones 7181
#  Entrenamiento completo  0.0 iteraciones 7597
#  Entrenamiento completo  0.0 iteraciones 7227
#  Entrenamiento completo  0.0 iteraciones 7481
#  Entrenamiento completo  0.0 iteraciones 7290
#  Entrenamiento completo  0.0 iteraciones 7201
#  Entrenamiento completo  0.0 iteraciones 7478
#  Entrenamiento completo  0.0 iteraciones 7462
#  Entrenamiento completo  0.0 iteraciones 6860
#  Entrenamiento completo  0.0 iteraciones 7585
#  Entrenamiento completo  0.0 iteraciones 7308
#  Entrenamiento completo  0.0 iteraciones 7252
#  Entrenamiento completo  0.0 iteraciones 7426
#  Entrenamiento completo  0.0 iteraciones 6819
#  Entrenamiento completo  0.0 iteraciones 7259
#  Entrenamiento completo  0.0 iteraciones 7242
#  Entrenamiento completo  0.0 iteraciones 5419
#  Entrenamiento completo  0.0 iteraciones 7037
#  Entrenamiento completo  0.0 iteraciones 7507
#  Entrenamiento completo  0.0 iteraciones 7349
#  Entrenamiento completo  0.0 iteraciones 7277
#  Entrenamiento completo  0.0 iteraciones 7265
#  Entrenamiento completo  0.0 iteraciones 7391
#  Entrenamiento completo  0.0 iteraciones 7370
#  Entrenamiento completo  0.0 iteraciones 7373
#  Entrenamiento completo  0.0 iteraciones 7196
#  Entrenamiento completo  0.0 iteraciones 7418
#  Entrenamiento completo  0.0 iteraciones 6559
#  Entrenamiento completo  0.0 iteraciones 7500
#  Entrenamiento completo  0.0 iteraciones 7449
#  Entrenamiento completo  0.0 iteraciones 7125
#  Entrenamiento completo  0.0 iteraciones 7935
#  Entrenamiento completo  0.0 iteraciones 7633
#  Entrenamiento completo  0.0 iteraciones 7430
#  Entrenamiento completo  0.0 iteraciones 7423
#  Entrenamiento completo  0.0 iteraciones 7495
#  Entrenamiento completo  0.0 iteraciones 7470
#  Entrenamiento completo  0.0 iteraciones 7127
#  Entrenamiento completo  0.0 iteraciones 7113
#  Entrenamiento completo  0.0 iteraciones 7255
#  Entrenamiento completo  0.0 iteraciones 7532
#  Entrenamiento completo  0.0 iteraciones 7422
#  Entrenamiento completo  0.0 iteraciones 6857
#  Entrenamiento completo  0.0 iteraciones 7170
#  Entrenamiento completo  0.0 iteraciones 7255
#  Entrenamiento completo  0.0 iteraciones 7259
#  Entrenamiento completo  0.0 iteraciones 7193
#  Entrenamiento completo  0.0 iteraciones 7473
#  Entrenamiento completo  0.0 iteraciones 7593
#  Entrenamiento completo  0.0 iteraciones 7472
#  Entrenamiento completo  0.0 iteraciones 6885
#  Entrenamiento completo  0.0 iteraciones 7368
#  Entrenamiento completo  0.0 iteraciones 6814
#  Entrenamiento completo  0.0 iteraciones 7090
#  Entrenamiento completo  0.0 iteraciones 7479
#  Entrenamiento completo  0.0 iteraciones 7386
#  Entrenamiento completo  0.0 iteraciones 6802
#  Entrenamiento completo  0.0 iteraciones 7477
#  Entrenamiento completo  0.0 iteraciones 7450
#  Entrenamiento completo  0.0 iteraciones 7271
#  Entrenamiento completo  0.0 iteraciones 6871
#  Entrenamiento completo  0.0 iteraciones 6809
#  Entrenamiento completo  0.0 iteraciones 7067
#  Entrenamiento completo  0.0 iteraciones 7425
#  Entrenamiento completo  0.0 iteraciones 7324
#  Entrenamiento completo  0.0 iteraciones 7275
#  Entrenamiento completo  0.0 iteraciones 7259
#  Entrenamiento completo  0.0 iteraciones 7170
#  Entrenamiento completo  0.0 iteraciones 7481
#  Entrenamiento completo  0.0 iteraciones 7176
#  Entrenamiento completo  0.0 iteraciones 7311
#  Entrenamiento completo  0.0 iteraciones 7239
#  Entrenamiento completo  0.0 iteraciones 7493
#  Entrenamiento completo  0.0 iteraciones 7426
#  Entrenamiento completo  0.0 iteraciones 7440
#  Entrenamiento completo  0.0 iteraciones 5924
#  Entrenamiento completo  0.0 iteraciones 6447
#  Entrenamiento completo  0.0 iteraciones 7088
#  Entrenamiento completo  0.0 iteraciones 7469
#  Entrenamiento completo  0.0 iteraciones 7360
#  Entrenamiento completo  0.0 iteraciones 7461
#  Entrenamiento completo  0.0 iteraciones 7017
#  Entrenamiento completo  0.0 iteraciones 7188
#  Entrenamiento completo  0.0 iteraciones 7482
#  Entrenamiento completo  0.0 iteraciones 7177
#  Entrenamiento completo  0.0 iteraciones 7126
#  Entrenamiento completo  0.0 iteraciones 6725
#  Entrenamiento completo  0.0 iteraciones 7852
#  Entrenamiento completo  0.0 iteraciones 7254
#  Entrenamiento completo  0.0 iteraciones 7074
#  Entrenamiento completo  0.0 iteraciones 7376
#  Entrenamiento completo  0.0 iteraciones 6938
#  Entrenamiento completo  0.0 iteraciones 6504
#  Entrenamiento completo  0.0 iteraciones 7457
#  Entrenamiento completo  0.0 iteraciones 7422
#  Entrenamiento completo  0.0 iteraciones 7171
#  Entrenamiento completo  0.0 iteraciones 7536
#  Entrenamiento completo  0.0 iteraciones 7462
#  Entrenamiento completo  0.0 iteraciones 6695
#  Entrenamiento completo  0.0 iteraciones 7245
#  Entrenamiento completo  0.0 iteraciones 7714
#  Entrenamiento completo  0.0 iteraciones 7436
#  Entrenamiento completo  0.0 iteraciones 7970
#  Entrenamiento completo  0.0 iteraciones 6496
#  Entrenamiento completo  0.0 iteraciones 7484
#  Entrenamiento completo  0.0 iteraciones 7233
#  Entrenamiento completo  0.0 iteraciones 7199
#  Entrenamiento completo  0.0 iteraciones 7104
#  Entrenamiento completo  0.0 iteraciones 7459
#  Entrenamiento completo  0.0 iteraciones 7105
#  Entrenamiento completo  0.0 iteraciones 6787
#  Entrenamiento completo  0.0 iteraciones 7446
#  Entrenamiento completo  0.0 iteraciones 7338
#  Entrenamiento completo  0.0 iteraciones 7134
#  Entrenamiento completo  0.0 iteraciones 7770
#  Entrenamiento completo  0.0 iteraciones 7366
#  Entrenamiento completo  0.0 iteraciones 7403
#  Entrenamiento completo  0.0 iteraciones 7485
#  Entrenamiento completo  0.0 iteraciones 6960
#  Entrenamiento completo  0.0 iteraciones 7466
#  Entrenamiento completo  0.0 iteraciones 7506
#  Entrenamiento completo  0.0 iteraciones 7670
#  Entrenamiento completo  0.0 iteraciones 7450
#  Entrenamiento completo  0.0 iteraciones 7287
#  Entrenamiento completo  0.0 iteraciones 7271
#  Entrenamiento completo  0.0 iteraciones 6754
#  Entrenamiento completo  0.0 iteraciones 6858
#  Entrenamiento completo  0.0 iteraciones 7478
#  Entrenamiento completo  0.0 iteraciones 7150
#  Entrenamiento completo  0.0 iteraciones 6450
#  Entrenamiento completo  0.0 iteraciones 6781
#  Entrenamiento completo  0.0 iteraciones 7688
#  Entrenamiento completo  0.0 iteraciones 7898
#  Entrenamiento completo  0.0 iteraciones 8247
#  Entrenamiento completo  0.0 iteraciones 7293
#  Entrenamiento completo  0.0 iteraciones 7474
#  Entrenamiento completo  0.0 iteraciones 7176
#  Entrenamiento completo  0.0 iteraciones 7520
#  Entrenamiento completo  0.0 iteraciones 7250
#  Entrenamiento completo  0.0 iteraciones 7444
#  Entrenamiento completo  0.0 iteraciones 7442
#  Entrenamiento completo  0.0 iteraciones 7453
#  Entrenamiento completo  0.0 iteraciones 7103
#  Entrenamiento completo  0.0 iteraciones 7322
#  Entrenamiento completo  0.0 iteraciones 7859
#  Entrenamiento completo  0.0 iteraciones 7228
#  Entrenamiento completo  0.0 iteraciones 7368
#  Entrenamiento completo  0.0 iteraciones 7462
#  Entrenamiento completo  0.0 iteraciones 7405
#  Entrenamiento completo  0.0 iteraciones 7482
#  Entrenamiento completo  0.0 iteraciones 7608
#  Entrenamiento completo  0.0 iteraciones 7291
#  Entrenamiento completo  0.0 iteraciones 7072
#  Entrenamiento completo  0.0 iteraciones 7454
#  Entrenamiento completo  0.0 iteraciones 7432
#  Entrenamiento completo  0.0 iteraciones 7291
#  Entrenamiento completo  0.0 iteraciones 7121
#  Entrenamiento completo  0.0 iteraciones 7050
#  Entrenamiento completo  0.0 iteraciones 7349
#  Entrenamiento completo  0.0 iteraciones 7117
#  Entrenamiento completo  0.0 iteraciones 7412
#  Entrenamiento completo  0.0 iteraciones 7443
#  Entrenamiento completo  0.0 iteraciones 7297
#  Entrenamiento completo  0.0 iteraciones 7192
#  Entrenamiento completo  0.0 iteraciones 7471
#  Entrenamiento completo  0.0 iteraciones 8008
#  Entrenamiento completo  0.0 iteraciones 7779
#  Entrenamiento completo  0.0 iteraciones 7015
#  Entrenamiento completo  0.0 iteraciones 7457
#  Entrenamiento completo  0.0 iteraciones 7191
#  Entrenamiento completo  0.0 iteraciones 7470
#  Entrenamiento completo  0.0 iteraciones 7409
#  Entrenamiento completo  0.0 iteraciones 7251
#  Entrenamiento completo  0.0 iteraciones 7021
#  Entrenamiento completo  0.0 iteraciones 7171
#  Entrenamiento completo  0.0 iteraciones 7259
#  Entrenamiento completo  0.0 iteraciones 7246
#  Entrenamiento completo  0.0 iteraciones 7322
#  Entrenamiento completo  0.0 iteraciones 7396
#  Entrenamiento completo  0.0 iteraciones 7101
#  Entrenamiento completo  0.0 iteraciones 7375
#  Entrenamiento completo  0.0 iteraciones 7273
#  Entrenamiento completo  0.0 iteraciones 7431
#  Entrenamiento completo  0.0 iteraciones 7158
#  Entrenamiento completo  0.0 iteraciones 7089
#  Entrenamiento completo  0.0 iteraciones 7455
#  Entrenamiento completo  0.0 iteraciones 7405
#  Entrenamiento completo  0.0 iteraciones 7023
#  Entrenamiento completo  0.0 iteraciones 6761
#  Entrenamiento completo  0.0 iteraciones 7308
#  Entrenamiento completo  0.0 iteraciones 7366
#  Entrenamiento completo  0.0 iteraciones 7612
#  Entrenamiento completo  0.0 iteraciones 7495
#  Entrenamiento completo  0.0 iteraciones 7485
#  Entrenamiento completo  0.0 iteraciones 7506
#  Entrenamiento completo  0.0 iteraciones 6975
#  Entrenamiento completo  0.0 iteraciones 7261
#  Entrenamiento completo  0.0 iteraciones 7496
#  Entrenamiento completo  0.0 iteraciones 7278
#  Entrenamiento completo  0.0 iteraciones 7330
#  Entrenamiento completo  0.0 iteraciones 7044
#  Entrenamiento completo  0.0 iteraciones 7192
#  Entrenamiento completo  0.0 iteraciones 7574
#  Entrenamiento completo  0.0 iteraciones 7440
#  Entrenamiento completo  0.0 iteraciones 7414
#  Entrenamiento completo  0.0 iteraciones 7150
#  Entrenamiento completo  0.0 iteraciones 7263
#  Entrenamiento completo  0.0 iteraciones 6875
#  Entrenamiento completo  0.0 iteraciones 7058
#  Entrenamiento completo  0.0 iteraciones 7247
#  Entrenamiento completo  0.0 iteraciones 7503
#  Entrenamiento completo  0.0 iteraciones 7205
#  Entrenamiento completo  0.0 iteraciones 7095
#  Entrenamiento completo  0.0 iteraciones 7077
#  Entrenamiento completo  0.0 iteraciones 7658
#  Entrenamiento completo  0.0 iteraciones 6660
#  Entrenamiento completo  0.0 iteraciones 7500
#  Entrenamiento completo  0.0 iteraciones 7437
#  Entrenamiento completo  0.0 iteraciones 7410
#  Entrenamiento completo  0.0 iteraciones 7251
#  Entrenamiento completo  0.0 iteraciones 7422
#  Entrenamiento completo  0.0 iteraciones 7996
#  Entrenamiento completo  0.0 iteraciones 7317
#  Entrenamiento completo  0.0 iteraciones 7123
#  Entrenamiento completo  0.0 iteraciones 7490
#  Entrenamiento completo  0.0 iteraciones 7919
#  Entrenamiento completo  0.0 iteraciones 7403
#  Entrenamiento completo  0.0 iteraciones 7497
#  Entrenamiento completo  0.0 iteraciones 6301
#  Entrenamiento completo  0.0 iteraciones 7154
#  Entrenamiento completo  0.0 iteraciones 7289
#  Entrenamiento completo  0.0 iteraciones 7438
#  Entrenamiento completo  0.0 iteraciones 7442
#  Entrenamiento completo  0.0 iteraciones 7608
#  Entrenamiento completo  0.0 iteraciones 7816
#  Entrenamiento completo  0.0 iteraciones 7382
#  Entrenamiento completo  0.0 iteraciones 7383
#  Entrenamiento completo  0.0 iteraciones 7769
#  Entrenamiento completo  0.0 iteraciones 7260
#  Entrenamiento completo  0.0 iteraciones 7464
#  Entrenamiento completo  0.0 iteraciones 7774
#  Entrenamiento completo  0.0 iteraciones 7259
#  Entrenamiento completo  0.0 iteraciones 7444
#  Entrenamiento completo  0.0 iteraciones 7503
#  Entrenamiento completo  0.0 iteraciones 7403
#  Entrenamiento completo  0.0 iteraciones 7050
#  Entrenamiento completo  0.0 iteraciones 7449
#  Entrenamiento completo  0.0 iteraciones 7299
#  Entrenamiento completo  0.0 iteraciones 7274
#  Entrenamiento completo  0.0 iteraciones 7249
#  Entrenamiento completo  0.0 iteraciones 7155
#  Entrenamiento completo  0.0 iteraciones 6496
#  Entrenamiento completo  0.0 iteraciones 7362
#  Entrenamiento completo  0.0 iteraciones 6902
#  Entrenamiento completo  0.0 iteraciones 6735
#  Entrenamiento completo  0.0 iteraciones 7508
#  Entrenamiento completo  0.0 iteraciones 7419
#  Entrenamiento completo  0.0 iteraciones 7154
#  Entrenamiento completo  0.0 iteraciones 7135
#  Entrenamiento completo  0.0 iteraciones 7439
#  Entrenamiento completo  0.0 iteraciones 7391
#  Entrenamiento completo  0.0 iteraciones 7077
#  Entrenamiento completo  0.0 iteraciones 7509
#  Entrenamiento completo  0.0 iteraciones 6820
#  Entrenamiento completo  0.0 iteraciones 7494
#  Entrenamiento completo  0.0 iteraciones 7141
#  Entrenamiento completo  0.0 iteraciones 7304
#  Entrenamiento completo  0.0 iteraciones 7431
#  Entrenamiento completo  0.0 iteraciones 7901
#  Entrenamiento completo  0.0 iteraciones 7481
#  Entrenamiento completo  0.0 iteraciones 7774
#  Entrenamiento completo  0.0 iteraciones 7401
#  Entrenamiento completo  0.0 iteraciones 7267
#  Entrenamiento completo  0.0 iteraciones 7375
#  Entrenamiento completo  0.0 iteraciones 7768
#  Entrenamiento completo  0.0 iteraciones 7410
#  Entrenamiento completo  0.0 iteraciones 7311
#  Entrenamiento completo  0.0 iteraciones 7489
#  Entrenamiento completo  0.0 iteraciones 7096
#  Entrenamiento completo  0.0 iteraciones 7756
#  Entrenamiento completo  0.0 iteraciones 7035
#  Entrenamiento completo  0.0 iteraciones 7386
#  Entrenamiento completo  0.0 iteraciones 7362
#  Entrenamiento completo  0.0 iteraciones 7148
#  Entrenamiento completo  0.0 iteraciones 7608
#  Entrenamiento completo  0.0 iteraciones 7170
#  Entrenamiento completo  0.0 iteraciones 7236
#  Entrenamiento completo  0.0 iteraciones 6461
#  Entrenamiento completo  0.0 iteraciones 7411
#  Entrenamiento completo  0.0 iteraciones 6769
#  Entrenamiento completo  0.0 iteraciones 7279
#  Entrenamiento completo  0.0 iteraciones 7029
#  Entrenamiento completo  0.0 iteraciones 7096
#  Entrenamiento completo  0.0 iteraciones 7107
#  Entrenamiento completo  0.0 iteraciones 7376
#  Entrenamiento completo  0.0 iteraciones 7010
#  Entrenamiento completo  0.0 iteraciones 7454
#  Entrenamiento completo  0.0 iteraciones 7188
#  Entrenamiento completo  0.0 iteraciones 7287
#  Entrenamiento completo  0.0 iteraciones 7437
#  Entrenamiento completo  0.0 iteraciones 7376
#  Entrenamiento completo  0.0 iteraciones 7328

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(1,1,1, projection = '3d')

ax.set_xlim3d(-1, 1)
ax.set_ylim3d(-1, 1)
ax.set_zlim3d(-1, 1)

ax.view_init(10, 60)
X=points[:,0]
Y=points[:,1]
Z=points[:,2]
ax.scatter(X,Y,Z)
plt.show()
